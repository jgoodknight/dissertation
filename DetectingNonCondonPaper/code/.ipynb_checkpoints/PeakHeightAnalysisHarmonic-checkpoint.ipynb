# %%
import math

import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt

import PeakTools

# %matplotlib notebook
# %matplotlib inline

# %%
MAX_ORDER = 4
o_list = [[1], [2],[3],[4], [1,2], [2,4], [1,3]]
USE_THETA = True

# %% [markdown]
# # Function to Fit
# \begin{align}
#     \frac{\tilde{E}_{NC}(\omega_{0,k+1})}{\tilde{E}_{NC}(\omega_{0,k})} = \frac{\epsilon(\omega_{0,k+1})}{\epsilon(\omega_{0,k})}	&= \left( \frac{\omega_{0,k+1}}{\omega_{0,k}}\right)^2 \frac{S }{k+1 } \frac{\left| 1 + c\sqrt{S} \left( 1  - \frac{k+1}{S} \right)\right|^2  }{\left| 1 + c \sqrt{S} \left( 1  - \frac{k}{S} \right) \right|^2 } \\
#     &= \left( \frac{\omega_{0,k+1}}{\omega_{0,k}}\right)^2 \frac{S }{k+1 } \frac{1 + 2 |c|\cos \theta \sqrt{S} \left( 1  - \frac{k+1}{S} \right) + |c|^2\left( 1  - \frac{k+1}{S} \right)^2 }{1 + 2 |c|\cos \theta \sqrt{S} \left( 1  - \frac{k}{S} \right) + |c|^2\left( 1  - \frac{k}{S} \right)^2 }\\
# 0 &= \frac{\epsilon(\omega_{0,k+1})}{\epsilon(\omega_{0,k})} \left( \frac{\omega_{0,k}}{\omega_{0,k+1}}\right)^2 - \frac{S }{k+1 } \frac{1 + 2 |c|\cos \theta \sqrt{S} \left( 1  - \frac{k+1}{S} \right) + |c|^2\left( 1  - \frac{k+1}{S} \right)^2 }{1 + 2 |c|\cos \theta \sqrt{S} \left( 1  - \frac{k}{S} \right) + |c|^2\left( 1  - \frac{k}{S} \right)^2 }
# \end{align}

# %% [markdown]
# # Citeable Tetracene in Toluene

# %% [markdown]
# ![See dat spectra...](tetracene_citeable_toluene.jpeg "Tetracene in Toluene")

# %%
#From DataThief
ZERO_PAD = 100

tetracene_toluene_spectra  = np.loadtxt("spectra_csv/tetracene_citeable_toluene.csv", delimiter=",")

tetracene_toluene_wavelength_nm = tetracene_toluene_spectra[:,0] 
tetracene_toluene_wavenumbers = 1 / (tetracene_toluene_wavelength_nm * 1e-7)
tetracene_toluene_abs = tetracene_toluene_spectra[:,1] 
# tetracene_toluene_abs = -np.log(tetracene_toluene_abs)
tetracene_toluene_abs = tetracene_toluene_abs - np.min(tetracene_toluene_abs)
tetracene_toluene_abs = tetracene_toluene_abs/tetracene_toluene_wavenumbers**2
tetracene_toluene_abs = tetracene_toluene_abs /np.max(tetracene_toluene_abs)

tetracene_toluene_wavenumbers, tetracene_toluene_abs = PeakTools.left_zero_pad_spectra(tetracene_toluene_wavenumbers, tetracene_toluene_abs, ZERO_PAD)

# %%
tetracene_toluene_peak_energy_guesses = [21053.0, 22505.0, 24057.0, 25368.0 , 26658.3, 28168.][0:-1]
tetracene_toluene_peak_height_guesses = [.95, .76, .35, .14, .05, .014][0:-1]
width_guess_wavenumbers = 100.0

# %%
tetracene_toluene_fit = PeakTools.SpectraFit(spectral_energies=tetracene_toluene_wavenumbers, 
                           spectral_amplitudes=tetracene_toluene_abs, 
                           approx_peak_energies = tetracene_toluene_peak_energy_guesses, 
                           approx_peak_heights = tetracene_toluene_peak_height_guesses, 
                           width_guess = width_guess_wavenumbers)

# %%
tetracene_toluene_fit.fit_and_observe_spectra()
# Out:
# PREPARING ANALYSIS FOR SPECTRA:
#
#
# ---------GAUSSIAN---------
#
# gaussian profile fit to spectra with cost 3.47282516499
# ('anharmonic fit', array([   -25.30163669,   1491.40759951,  20363.92763647]))
# ('chi', 0.016964937485633585)
# max bound n=28
# r^2=0.999908581893
#
# ---------LORENTZIAN---------
#
# lorentzian profile fit to spectra with cost 1.71378128041
# ('anharmonic fit', array([ -1.24275241e+01,   1.45385320e+03,   2.03792509e+04]))
# ('chi', 0.0085479909658361924)
# max bound n=57
# r^2=0.999956578603
#
# ---------VOIGT---------
#
# voigt profile fit to spectra with cost 1.01412956895
# ('anharmonic fit', array([  1.16020553e+00,   1.38886550e+03,   2.04200642e+04]))
# ('chi', -0.00083536204912974896)
# max bound n=-600
# r^2=0.999951724536
#
#
# BEST METHOD WAS: voigt

# %%
tetracene_toluene_fit.plot_spectral_fit(["voigt"])
# plt.title("Tetracene in Toluene")
plt.xlabel(r"$\omega$ / wavenumbers")
plt.ylabel(r"Normalized $K$")
plt.legend(loc=0)
plt.savefig("toluene_spectra_fit.png", dpi=900)

# %%
tetracene_toluene_fit.explore_non_condon_orders(max_order=None, order_lists_to_calculate = o_list, method_str="voigt", use_theta=USE_THETA)
# Out:
# [1] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 1 better models were found
# HO/c model fit Found for voigt!  S=1.18515164775, c=[-0.], theta/pi=[ 0.]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 0.936810309374 	 improvement_factor = 1.0
#
#
#
# BEST METHOD WAS: voigt
# [2] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 3 better models were found
# HO/c model fit Found for voigt!  S=1.20149061029, c=[ 0.00562089], theta/pi=[  4.33984214e-05]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 0.935205145673 	 improvement_factor = 0.998286564862
#
#
#
# BEST METHOD WAS: voigt
# [3] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 3 better models were found
# HO/c model fit Found for voigt!  S=1.0977079917, c=[-0.22398523], theta/pi=[ 1.50403181]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 0.980548813164 	 improvement_factor = 1.04668875156
#
#
#
# BEST METHOD WAS: voigt
# [4] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 3 better models were found
# HO/c model fit Found for voigt!  S=1.08888025199, c=[-0.01299374], theta/pi=[  1.27611229e-06]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 0.987946763909 	 improvement_factor = 1.05458570857
#
#
#
# BEST METHOD WAS: voigt
# [1, 2] order non-condon perturbation calculation
#
# ---------VOIGT---------
# PeakTools.py:205: UserWarning: HO_overlap fed negative Huang Rhys factor!  performing absolute value operation
#   warnings.warn("HO_overlap fed negative Huang Rhys factor!  performing absolute value operation")
# Through running 5 lstsq attempts, 2 better models were found
# HO/c model fit Found for voigt!  S=0.651563532149, c=[-0.4788733 -0.1738012], theta/pi=[ 1.59511561  0.31964342]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 0.978791649396 	 improvement_factor = 1.04481306365
#
#
#
# BEST METHOD WAS: voigt
# [2, 4] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 4 better models were found
# HO/c model fit Found for voigt!  S=1.18515865576, c=[ 0.53953676  0.34064732], theta/pi=[ 0.42755441  0.43564569]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 1.0 	 improvement_factor = 1.06745195905
#
#
#
# BEST METHOD WAS: voigt
# [1, 3] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 3 better models were found
# HO/c model fit Found for voigt!  S=1.18515164775, c=[ 0.22168711  0.17986213], theta/pi=[ 1.7150624   0.54482804]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 1.0 	 improvement_factor = 1.06745195905
#
#
#
# BEST METHOD WAS: voigt
# [1, 3] order non-condon perturbation fit the spectra best!
# cost report:
# (4.157327044511704e-22, [1, 3])
# (1.3719475009789419e-17, [2, 4])
# (0.0071594572472638155, [3])
# (0.031702120257753603, [4])
# (0.036968210079755218, [1, 2])
# (0.046324390374904358, [2])
# (0.046533910937935741, [1])

# %%
tetracene_toluene_fit.fit_and_observe_non_condon_models(order=[2], plot_spectra=False, my_methods_list=["voigt"], use_theta=USE_THETA)
plt.savefig("toluene_ratio_fit_2.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.20149061029, c=[ 0.00562089], theta/pi=[  4.33984214e-05]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 0.935205145673 	 improvement_factor = 0.998286564862
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = 0.829354836412 	 r^2_model = 0.830123204904 	 improvement_factor = 1.00092646532

# %%
tetracene_toluene_fit.fit_and_observe_non_condon_models(order =[1,3], plot_spectra=False, my_methods_list=["voigt"], use_theta=USE_THETA)
plt.savefig("toluene_ratio_fit_13.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [1, 3]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.18515164775, c=[ 0.22168711  0.17986213], theta/pi=[ 1.7150624   0.54482804]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 1.0 	 improvement_factor = 1.06745195905
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = 0.829354836412 	 r^2_model = 1.0 	 improvement_factor = 1.20575651831

# %%
tetracene_toluene_fit.fit_and_observe_non_condon_models(order =[2,4], plot_spectra=False, my_methods_list=["voigt"], use_theta=USE_THETA)
plt.savefig("toluene_ratio_fit_24.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2, 4]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.18515865576, c=[ 0.53953676  0.34064732], theta/pi=[ 0.42755441  0.43564569]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 1.0 	 improvement_factor = 1.06745195905
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = 0.829354836412 	 r^2_model = 1.0 	 improvement_factor = 1.20575651831

# %% [markdown]
# # Tetracene in DCE
# ## Orange in the image below

# %% [markdown]
# ![See dat spectra...](tetracene_citeable_dichloroethene.png "Tetracene in DCE")

# %%
#From DataThief
tetracene_dce_spectra  = np.loadtxt("spectra_csv/tetracene_citeable_dichloroethene.csv", delimiter=",")

tetracene_dce_wavelength_nm = tetracene_dce_spectra[:,0] 
tetracene_dce_wavenumbers = 1 / (tetracene_dce_wavelength_nm * 1e-7)
tetracene_dce_abs = tetracene_dce_spectra[:,1]
tetracene_dce_abs = tetracene_dce_abs - np.min(tetracene_dce_abs)
tetracene_dce_abs = tetracene_dce_abs/tetracene_dce_wavenumbers**2
tetracene_dce_abs = tetracene_dce_abs / np.max(tetracene_dce_abs)
tetracene_dce_abs = np.flipud(tetracene_dce_abs)
tetracene_dce_wavenumbers= np.flipud(tetracene_dce_wavenumbers)

# %%
ZERO_PAD = 100

tetracene_dce_wavenumbers, tetracene_dce_abs = PeakTools.left_zero_pad_spectra(tetracene_dce_wavenumbers, tetracene_dce_abs, ZERO_PAD)

# %%
tetracene_dcm_peak_energy_guesses = [21053.0, 22505.0, 24057.0, 25368.0 , 26658.3, 28114.]
tetracene_dcm_peak_height_guesses = [.97, .82, .37, .15, .05, .01]
#maybe rpeplace with the toluene numbers.  they worked well enough
width_guess_wavenumbers = 100.0

# %%
tetracene_dce_fit = PeakTools.SpectraFit(spectral_energies=tetracene_dce_wavenumbers, 
                           spectral_amplitudes=tetracene_dce_abs, 
                           approx_peak_energies = tetracene_dcm_peak_energy_guesses, 
                           approx_peak_heights = tetracene_dcm_peak_height_guesses, 
                           width_guess = width_guess_wavenumbers)

# %%
tetracene_dce_fit.fit_and_observe_spectra()
# Out:
# PREPARING ANALYSIS FOR SPECTRA:
#
#
# ---------GAUSSIAN---------
#
# gaussian profile fit to spectra with cost 1.36519348402
# ('anharmonic fit', array([ -3.49366039e+00,   1.39781191e+03,   2.04450937e+04]))
# ('chi', 0.0024993780443916809)
# max bound n=199
# r^2=0.999500307673
#
# ---------LORENTZIAN---------
#
# lorentzian profile fit to spectra with cost 1.84596906801
# ('anharmonic fit', array([ -9.59656420e+00,   1.45319402e+03,   2.03859274e+04]))
# ('chi', 0.0066037735037344893)
# max bound n=74
# r^2=0.99998815568
#
# ---------VOIGT---------
#
# voigt profile fit to spectra with cost 0.823995752589
# ('anharmonic fit', array([   -27.66314899,   1529.72331298,  20332.98326781]))
# ('chi', 0.018083759823415323)
# max bound n=26
# r^2=0.999459755738
#
#
# BEST METHOD WAS: voigt

# %%
tetracene_dce_fit.plot_spectral_fit(["voigt"])
# plt.title("Tetracene in DCM")
plt.xlabel(r"$\omega$ / wavenumbers")
plt.ylabel(r"Normalized $K$")
plt.legend(loc=0)
plt.savefig("dcm_spectra_fit.png", dpi=900)

# %%
tetracene_dce_fit.explore_non_condon_orders(max_order = None, order_lists_to_calculate=o_list, method_str="voigt", use_theta=USE_THETA)
# Out:
# [1] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 1 better models were found
# HO/c model fit Found for voigt!  S=1.4897076238, c=[-0.], theta/pi=[ 0.]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.788399099934 	 improvement_factor = 1.0
#
#
#
# BEST METHOD WAS: voigt
# [2] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 4 better models were found
# HO/c model fit Found for voigt!  S=1.26266574972, c=[-0.06693415], theta/pi=[ 1.99993928]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.838762590028 	 improvement_factor = 1.06388070471
#
#
#
# BEST METHOD WAS: voigt
# [3] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 3 better models were found
# HO/c model fit Found for voigt!  S=1.31914212373, c=[ 0.34399278], theta/pi=[ 1.47491014]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.94478856692 	 improvement_factor = 1.19836332512
#
#
#
# BEST METHOD WAS: voigt
# [4] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 2 better models were found
# HO/c model fit Found for voigt!  S=1.37028749393, c=[-0.01341007], theta/pi=[  8.84699313e-06]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.910141477698 	 improvement_factor = 1.15441719527
#
#
#
# BEST METHOD WAS: voigt
# [1, 2] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 1 better models were found
# HO/c model fit Found for voigt!  S=1.14784261384, c=[-0.09157187 -0.07374074], theta/pi=[ 1.66427063  0.09166628]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.85429320656 	 improvement_factor = 1.08357963198
#
#
#
# BEST METHOD WAS: voigt
# [2, 4] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 3 better models were found
# HO/c model fit Found for voigt!  S=1.29016379758, c=[-0.76327226 -0.31040066], theta/pi=[ 0.45106837  0.49222063]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.977507152269 	 improvement_factor = 1.23986335392
#
#
#
# BEST METHOD WAS: voigt
# [1, 3] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 5 lstsq attempts, 1 better models were found
# HO/c model fit Found for voigt!  S=1.17355302567, c=[-0.27719554 -0.23681054], theta/pi=[ 1.33865487  0.39807334]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.99673967089 	 improvement_factor = 1.26425774836
#
#
#
# BEST METHOD WAS: voigt
# [2, 4] order non-condon perturbation fit the spectra best!
# cost report:
# (0.0059392090690727727, [2, 4])
# (0.02260548188930336, [1, 3])
# (0.055099463155493571, [3])
# (0.15085252208793506, [1, 2])
# (0.15265334737617003, [2])
# (0.17457850668354002, [4])
# (0.20589064841671373, [1])

# %%
tetracene_toluene_fit.fit_and_observe_non_condon_models([2], plot_spectra=False, my_methods_list=["voigt"], use_theta=USE_THETA)
plt.savefig("toluene_ratio_fit_2.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.20149061029, c=[ 0.00562089], theta/pi=[  4.33984214e-05]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 0.935205145673 	 improvement_factor = 0.998286564862
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = 0.829354836412 	 r^2_model = 0.830123204904 	 improvement_factor = 1.00092646532

# %%
tetracene_dce_fit.fit_and_observe_non_condon_models([2], plot_spectra=False, my_methods_list=["voigt"], use_theta=USE_THETA)
plt.savefig("dcm_ratio_fit_2.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.26266574972, c=[-0.06693415], theta/pi=[ 1.99993928]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.838762590028 	 improvement_factor = 1.06388070471
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = 0.773843211299 	 r^2_model = 0.832685587313 	 improvement_factor = 1.07603914482

# %%
order = [2,4]
tfs=True
method = "voigt"
tetracene_dce_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method], use_theta=USE_THETA)
plt.savefig("dcm_ratio_fit_24.png")
tetracene_toluene_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method], use_theta=USE_THETA)
plt.savefig("toluene_ratio_fit_24.png", dpi=900)

x = np.linspace(-3,3)
tfs=False
plt.figure()
tetracene_dce_fit.plot_transition_dipole(x, c_order = order, method_str=method, re_im_split=tfs, label_prefix = "DCM")
tetracene_toluene_fit.plot_transition_dipole(x, c_order = order, method_str=method, re_im_split=tfs, label_prefix="Toluene")
plt.legend(loc=0)
plt.title(r"Transition Dipole From $H_{%s}$"% order)
plt.savefig("dipole_comparison_24.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2, 4]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.29016379758, c=[-0.76327226 -0.31040066], theta/pi=[ 0.45106837  0.49222063]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.977507152269 	 improvement_factor = 1.23986335392
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = 0.773843211299 	 r^2_model = 0.993693874102 	 improvement_factor = 1.28410233442
# PREPARING ANALYSIS FOR A [2, 4]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.18515865576, c=[ 0.53953676  0.34064732], theta/pi=[ 0.42755441  0.43564569]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 1.0 	 improvement_factor = 1.06745195905
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = 0.829354836412 	 r^2_model = 1.0 	 improvement_factor = 1.20575651831
# ('test loc 2', [2, 4])
# [c2,c4] = [(0.15416757381981197+0.19195868459362131j), (-0.022627641444234459-0.048752694208519791j)]
# (0.15416757382+0.191958684594j) * x^2
# (-0.0226276414442-0.0487526942085j) * x^4
# ('test loc 2', [2, 4])
# [c2,c4] = [(0.002162227777102111-0.10620228836731042j), (-0.0081018450640921377+0.070762049374135605j)]
# (0.0021622277771-0.106202288367j) * x^2
# (-0.00810184506409+0.0707620493741j) * x^4

# %%
order = [1,3]
method = "voigt"
tfs=True
tetracene_dce_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method], use_theta=USE_THETA)
plt.savefig("dcm_ratio_fit_13.png")
tetracene_toluene_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method], use_theta=USE_THETA)
plt.savefig("toluene_ratio_fit_13.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [1, 3]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.17355302567, c=[-0.27719554 -0.23681054], theta/pi=[ 1.33865487  0.39807334]
# Naively S=1.4897076238 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.788399099934 	 r^2_model = 0.99673967089 	 improvement_factor = 1.26425774836
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = 0.773843211299 	 r^2_model = 0.976541194128 	 improvement_factor = 1.26193675911
# PREPARING ANALYSIS FOR A [1, 3]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.18515164775, c=[ 0.22168711  0.17986213], theta/pi=[ 1.7150624   0.54482804]
# Naively S=1.18515164775 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = 0.936810309374 	 r^2_model = 1.0 	 improvement_factor = 1.06745195905
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = 0.829354836412 	 r^2_model = 1.0 	 improvement_factor = 1.20575651831

# %%
x = np.linspace(-3,3)
tfs=False
plt.figure()
tetracene_dce_fit.plot_transition_dipole(x, c_order = order, method_str=method, re_im_split=tfs, label_prefix = "DCM")
tetracene_toluene_fit.plot_transition_dipole(x, c_order = order, method_str=method, re_im_split=tfs, label_prefix="Toluene")
plt.legend(loc=0)
plt.title(r"Transition Dipole From $H_{%s}$"% order)
plt.savefig("dipole_comparison_13.png", dpi=900)
# Out:
# ('test loc 2', [1, 3])
# [c1,c3] = [(0.19542720396752658+0.42586832304555999j), (-0.03043096732917619-0.091763256193438503j)]
# (0.195427203968+0.425868323046j) * x^1
# (-0.0304309673292-0.0917632561934j) * x^3
# ('test loc 2', [1, 3])
# [c1,c3] = [(0.15925590865950895-0.31838706107294446j), (-0.010306879026830647+0.072701439579089117j)]
# (0.15925590866-0.318387061073j) * x^1
# (-0.0103068790268+0.0727014395791j) * x^3

# %%
def table_generator(order, spectra_fit_1, label_1, spectra_fit_2, label_2, method_str="voigt"):
    
    (HO_params_1, condon_S_1, fit_cost_1) = spectra_fit_1.methodOrderTuple_to_HO_params[tuple_key]
    (HO_params_2, condon_S_2, fit_cost_2) = spectra_fit_2.methodOrderTuple_to_HO_params[tuple_key]
    (best_S_1, best_c_1, best_theta_1) = HO_params_1
    (best_S_2, best_c_2, best_theta_2) = HO_params_2
    
    fit_params_1 = spectra_fit_1.method_to_fit_params[method_str]
    (best_centers_1, best_heights_1, best_widths_1) = fit_params_1
    actual_ratios = []
    for i in range(1, len(actual_peaks)):
        actual_ratios.append(best_heights_1[i] / best_heights_1[i - 1])
    predicted_ratios = PeakTools.predicted_peak_intensities_clist(range(len(actual_ratios)), best_S_1, best_c_1, best_theta_1, order, ratios=True)
    r2_1 = PeakTools.r_squared(actual_ratios, predicted_ratios)
    
    
    fit_params_2 = spectra_fit_2.method_to_fit_params[method_str]
    (best_centers_2, best_heights_2, best_widths_2) = fit_params_2
    actual_ratios = []
    for i in range(1, len(actual_peaks)):
        actual_ratios.append(best_heights_2[i] / best_heights_2[i - 1])
    predicted_ratios = PeakTools.predicted_peak_intensities_clist(range(len(actual_ratios)), best_S_2, best_c_1, best_theta_1, order, ratios=True)
    r2_2 = PeakTools.r_squared(actual_ratios, predicted_ratios)
    
    print("  & {}  &  {} \\".format(label_1, label_2))
    print(" S_\{({})\} & {:.3f}  &  {:.3f} \\".format(order, best_S_1, best_S_2))
    for i, o in enumerate(order):
        print(" c'_\{ {} \} & {:.3f}  &  {:.3f} \\".format(o, best_c_1[i], best_c_2[i]))
        print(" \theta'_\{ {} \} / \pi & {:.3f}  &  {:.3f} \\".format(o, best_theta_1[i], best_theta_2[i]))
    print(" r^2_\{({})\} & {:.3f}  &  {:.3f} \\".format(order, r2_1, r2_2))

# %%
fit_params = self.method_to_fit_params[method_str]

        (best_S, best_c, best_theta) = HO_params
        (best_centers, best_heights, best_widths) = fit_params

        indeces = range(len(best_centers)-1)
        best_fit_HO_peaks = predicted_peak_intensities_clist(indeces, best_S, best_c, best_theta, c_order)

        condon_S = fit_condon(best_heights)

        best_fit_condon_peaks = predicted_peak_intensities_clist(indeces, condon_S, [0.0], [0.0], [0])

        actual_peaks = best_heights/best_heights[0]
        r2_condon = r_squared(data = actual_peaks, prediction = best_fit_condon_peaks)
        r2_model = r_squared(data = actual_peaks, prediction = best_fit_HO_peaks)
