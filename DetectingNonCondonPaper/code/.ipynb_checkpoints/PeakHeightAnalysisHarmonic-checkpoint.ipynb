# %%
import math

import numpy as np
import scipy.optimize
import matplotlib.pyplot as plt
import scipy

import PeakTools

# %matplotlib notebook
# %matplotlib inline

# %%
PeakTools.harmonic_peak_height_ratio_klist_clist([1,2,3,4,5,6],.5, [.1,.1,.1,.1],[1,2,3,4])
# Out:
# array([ 3.00918204,  2.25096114,  1.91768977,  1.72065197,  1.59839958,
#         1.50625163])

# %%
MAX_ORDER = 4
o_list = [[1], [2], [3],[4],[5],[6],[7], [1,2], [2,4], [1,3], [5,3,1]]

# %% [markdown]
# # Function to Fit
# \begin{align}
#     \frac{\tilde{E}_{NC}(\omega_{0,k+1})}{\tilde{E}_{NC}(\omega_{0,k})} = \frac{\epsilon(\omega_{0,k+1})}{\epsilon(\omega_{0,k})}	&= \left( \frac{\omega_{0,k+1}}{\omega_{0,k}}\right)^2 \frac{S }{k+1 } \frac{\left| 1 + c\sqrt{S} \left( 1  - \frac{k+1}{S} \right)\right|^2  }{\left| 1 + c \sqrt{S} \left( 1  - \frac{k}{S} \right) \right|^2 } \\
#     &= \left( \frac{\omega_{0,k+1}}{\omega_{0,k}}\right)^2 \frac{S }{k+1 } \frac{1 + 2 |c|\cos \theta \sqrt{S} \left( 1  - \frac{k+1}{S} \right) + |c|^2\left( 1  - \frac{k+1}{S} \right)^2 }{1 + 2 |c|\cos \theta \sqrt{S} \left( 1  - \frac{k}{S} \right) + |c|^2\left( 1  - \frac{k}{S} \right)^2 }\\
# 0 &= \frac{\epsilon(\omega_{0,k+1})}{\epsilon(\omega_{0,k})} \left( \frac{\omega_{0,k}}{\omega_{0,k+1}}\right)^2 - \frac{S }{k+1 } \frac{1 + 2 |c|\cos \theta \sqrt{S} \left( 1  - \frac{k+1}{S} \right) + |c|^2\left( 1  - \frac{k+1}{S} \right)^2 }{1 + 2 |c|\cos \theta \sqrt{S} \left( 1  - \frac{k}{S} \right) + |c|^2\left( 1  - \frac{k}{S} \right)^2 }
# \end{align}

# %% [markdown]
# # Citeable Tetracene in Toluene

# %% [markdown]
# ![See dat spectra...](tetracene_citeable_toluene.jpeg "Tetracene in Toluene")

# %%
#From DataThief
ZERO_PAD = 100

tetracene_toluene_spectra  = np.loadtxt("spectra_csv/tetracene_citeable_toluene.csv", delimiter=",")

tetracene_toluene_wavelength_nm = tetracene_toluene_spectra[:,0] 
tetracene_toluene_wavenumbers = 1 / (tetracene_toluene_wavelength_nm * 1e-7)
tetracene_toluene_abs = tetracene_toluene_spectra[:,1] 
# tetracene_toluene_abs = -np.log(tetracene_toluene_abs)
tetracene_toluene_abs = tetracene_toluene_abs - np.min(tetracene_toluene_abs)
tetracene_toluene_abs = tetracene_toluene_abs/tetracene_toluene_wavenumbers**2
tetracene_toluene_abs = tetracene_toluene_abs /np.max(tetracene_toluene_abs)

tetracene_toluene_wavenumbers, tetracene_toluene_abs = PeakTools.left_zero_pad_spectra(tetracene_toluene_wavenumbers, tetracene_toluene_abs, ZERO_PAD)

# %%
tetracene_toluene_peak_energy_guesses = [21053.0, 22505.0, 24057.0, 25368.0 , 26658.3, 28168.][0:-1]
tetracene_toluene_peak_height_guesses = [.95, .76, .35, .14, .05, .014][0:-1]
width_guess_wavenumbers = 100.0

# %%
tetracene_toluene_fit = PeakTools.SpectraFit(spectral_energies=tetracene_toluene_wavenumbers, 
                           spectral_amplitudes=tetracene_toluene_abs, 
                           approx_peak_energies = tetracene_toluene_peak_energy_guesses, 
                           approx_peak_heights = tetracene_toluene_peak_height_guesses, 
                           width_guess = width_guess_wavenumbers)

# %%
tetracene_toluene_fit.fit_and_observe_spectra()
# Out:
# PREPARING ANALYSIS FOR SPECTRA:
#
#
# ---------GAUSSIAN---------
#
# gaussian profile fit to spectra with cost 3.47282516499
# sqrt-diagonal valus
# ('anharmonic fit', array([   -25.30163669,   1491.40759951,  20363.92763647]))
# ('chi', 0.016964937485633585)
# max bound n=28
# r^2=0.999908581893
#
# ---------LORENTZIAN---------
#
# lorentzian profile fit to spectra with cost 1.71378128041
# sqrt-diagonal valus
# ('anharmonic fit', array([ -1.24275241e+01,   1.45385320e+03,   2.03792509e+04]))
# ('chi', 0.0085479909658361924)
# max bound n=57
# r^2=0.999956578603
#
# ---------VOIGT---------
#
# voigt profile fit to spectra with cost 1.01412956895
# sqrt-diagonal valus
# ('anharmonic fit', array([  1.16020553e+00,   1.38886550e+03,   2.04200642e+04]))
# ('chi', -0.00083536204912974896)
# max bound n=-600
# r^2=0.999951724536
#
#
# BEST METHOD WAS: voigt

# %%
tetracene_toluene_fit.plot_spectral_fit(["voigt"])
# plt.title("Tetracene in Toluene")
plt.xlabel(r"$\omega$ / wavenumbers")
plt.ylabel(r"Normalized $K$")
plt.legend(loc=0)
plt.savefig("toluene_spectra_fit.png", dpi=900)

# %%
tetracene_toluene_fit.explore_non_condon_orders(max_order=None, order_lists_to_calculate = o_list, method_str="voigt")
# Out:
# [1] order non-condon perturbation calculation
#
# ---------VOIGT---------
# PeakTools.py:205: UserWarning: HO_overlap fed negative Huang Rhys factor!  performing absolute value operation
#   warnings.warn("HO_overlap fed negative Huang Rhys factor!  performing absolute value operation")
# PeakTools.py:265: RuntimeWarning: invalid value encountered in divide
#   return numerator / denominator
# Through running 50 lstsq attempts, 2 better models were found
#
#
#  relative parameter errors for order[1]: [-4773478.5999605069]
#
#
# check for big off-diagonal values:
# [[  4.52582653e-04   1.00093845e+13]
#  [  1.00093845e+13   3.27657599e+30]]
#
#
# HO/c model fit Found for voigt!  S=0.691133414304, c=[ -3.79205949e+08]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.729396052821 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [2] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 10 better models were found
#
#
#  relative parameter errors for order[2]: [-0.061495124914203336]
#
#
# check for big off-diagonal values:
# [[  3.65793899e-02   6.45387596e-04]
#  [  6.45387596e-04   1.36539220e-05]]
#
#
# HO/c model fit Found for voigt!  S=1.65721203597, c=[-0.06008804]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.958162343631 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [1, 2] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 6 better models were found
#
#
#  relative parameter errors for order[1, 2]: [0.57708376700689012]
#
#
# check for big off-diagonal values:
# [[ 0.0307555   0.06210663 -0.00446449]
#  [ 0.06210663  0.32754955 -0.0127071 ]
#  [-0.00446449 -0.0127071   0.00301585]]
#
#
# HO/c model fit Found for voigt!  S=1.48917585577, c=[-1.47454894  0.0951626 ]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.791769972957 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [2, 4] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 2 better models were found
#
#
#  relative parameter errors for order[2, 4]: [9.6068105506835355]
#
#
# check for big off-diagonal values:
# [[  8.45348483e-02   1.95498229e+01  -4.12161493e-01]
#  [  1.95498229e+01   9.75673659e+03  -2.04279649e+02]
#  [ -4.12161493e-01  -2.04279649e+02   4.27732270e+00]]
#
#
# HO/c model fit Found for voigt!  S=1.42787962841, c=[-10.34675596   0.21528154]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.782918848916 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [1, 3] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 3 better models were found
#
#
#  relative parameter errors for order[1, 3]: [0.54161072439895974]
#
#
# check for big off-diagonal values:
# [[  8.50885637e-03   1.63044192e-01  -4.28615859e-03]
#  [  1.63044192e-01   3.57656374e+00  -9.30212554e-02]
#  [ -4.28615859e-03  -9.30212554e-02   2.42306891e-03]]
#
#
# HO/c model fit Found for voigt!  S=0.737948570315, c=[-3.83083747  0.09088571]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.989470735081 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [5, 3, 1] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 6 better models were found
#
#
#  relative parameter errors for order[5, 3, 1]: [-0.0034268092625728457]
#
#
# check for big off-diagonal values:
# [[  9.59753560e-06   2.76723879e-08  -1.25271778e-06   1.06851637e-05]
#  [  2.76723879e-08   9.26044731e-11  -4.29019101e-09   3.85477942e-08]
#  [ -1.25271778e-06  -4.29019101e-09   2.01355695e-07  -1.86220667e-06]
#  [  1.06851637e-05   3.85477942e-08  -1.86220667e-06   1.84894302e-05]]
#
#
# HO/c model fit Found for voigt!  S=0.713994164939, c=[-0.00136174  0.08132911 -1.25479226]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.999999739669 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [5, 3, 1] order non-condon perturbation fit the spectra best!
# cost report:
# (0.00011048813702996451, [5, 3, 1])
# (0.0041538939587352367, [1, 3])
# (0.072869123099601293, [2, 4])
# (0.086939867392911999, [1, 2])
# (0.092142633196177798, [1])
# (0.15880202196668891, [2])

# %%
tetracene_toluene_fit.fit_and_observe_non_condon_models(order=[2], plot_spectra=False, my_methods_list=["voigt"])
plt.savefig("toluene_ratio_fit_2.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.65721203597, c=[-0.06008804]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.958162343631 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -10.7211600702 	 improvement_factor = nan

# %%
tetracene_toluene_fit.fit_and_observe_non_condon_models(order =[1,3], plot_spectra=False, my_methods_list=["voigt"])
plt.savefig("toluene_ratio_fit_13.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [1, 3]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=0.737948570315, c=[-3.83083747  0.09088571]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.989470735081 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -7.09427451513 	 improvement_factor = nan

# %%
tetracene_toluene_fit.fit_and_observe_non_condon_models(order =[2,4], plot_spectra=False, my_methods_list=["voigt"])
plt.savefig("toluene_ratio_fit_24.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2, 4]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.42787962841, c=[-10.34675596   0.21528154]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.782918848916 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -7.59487896447 	 improvement_factor = nan

# %%
tetracene_toluene_fit.fit_and_observe_non_condon_models(order =[5,3,1], plot_spectra=False, my_methods_list=["voigt"])
plt.savefig("toluene_ratio_fit_531.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [5, 3, 1]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=0.713994164939, c=[-0.00136174  0.08132911 -1.25479226]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.999999739669 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -6.99574003073 	 improvement_factor = nan

# %% [markdown]
# # Tetracene in DCE
# ## Orange in the image below

# %% [markdown]
# ![See dat spectra...](tetracene_citeable_dichloroethene.png "Tetracene in DCE")

# %%
#From DataThief
tetracene_dce_spectra  = np.loadtxt("spectra_csv/tetracene_citeable_dichloroethene.csv", delimiter=",")

tetracene_dce_wavelength_nm = tetracene_dce_spectra[:,0] 
tetracene_dce_wavenumbers = 1 / (tetracene_dce_wavelength_nm * 1e-7)
tetracene_dce_abs = tetracene_dce_spectra[:,1]
tetracene_dce_abs = tetracene_dce_abs - np.min(tetracene_dce_abs)
tetracene_dce_abs = tetracene_dce_abs/tetracene_dce_wavenumbers**2
tetracene_dce_abs = tetracene_dce_abs / np.max(tetracene_dce_abs)
tetracene_dce_abs = np.flipud(tetracene_dce_abs)
tetracene_dce_wavenumbers= np.flipud(tetracene_dce_wavenumbers)

# %%
ZERO_PAD = 100

tetracene_dce_wavenumbers, tetracene_dce_abs = PeakTools.left_zero_pad_spectra(tetracene_dce_wavenumbers, tetracene_dce_abs, ZERO_PAD)

# %%
tetracene_dcm_peak_energy_guesses = [21053.0, 22505.0, 24057.0, 25368.0 , 26658.3, 28114.]
tetracene_dcm_peak_height_guesses = [.97, .82, .37, .15, .05, .01]
#maybe rpeplace with the toluene numbers.  they worked well enough
width_guess_wavenumbers = 100.0

# %%
tetracene_dce_fit = PeakTools.SpectraFit(spectral_energies=tetracene_dce_wavenumbers, 
                           spectral_amplitudes=tetracene_dce_abs, 
                           approx_peak_energies = tetracene_dcm_peak_energy_guesses, 
                           approx_peak_heights = tetracene_dcm_peak_height_guesses, 
                           width_guess = width_guess_wavenumbers)

# %%
tetracene_dce_fit.fit_and_observe_spectra()
# Out:
# PREPARING ANALYSIS FOR SPECTRA:
#
#
# ---------GAUSSIAN---------
#
# gaussian profile fit to spectra with cost 1.36519348402
# sqrt-diagonal valus
# ('anharmonic fit', array([ -3.49366960e+00,   1.39781195e+03,   2.04450937e+04]))
# ('chi', 0.0024993845616929971)
# max bound n=199
# r^2=0.999500307945
#
# ---------LORENTZIAN---------
#
# lorentzian profile fit to spectra with cost 1.84596906859
# sqrt-diagonal valus
# ('anharmonic fit', array([ -9.59638237e+00,   1.45319321e+03,   2.03859280e+04]))
# ('chi', 0.0066036520770615201)
# max bound n=74
# r^2=0.999988155358
#
# ---------VOIGT---------
#
# voigt profile fit to spectra with cost 0.823995752564
# sqrt-diagonal valus
# ('anharmonic fit', array([   -27.663152  ,   1529.7233185 ,  20332.98325463]))
# ('chi', 0.018083761724884816)
# max bound n=26
# r^2=0.999459755074
#
#
# BEST METHOD WAS: voigt

# %%
tetracene_dce_fit.plot_spectral_fit(["voigt"])
# plt.title("Tetracene in DCM")
plt.xlabel(r"$\omega$ / wavenumbers")
plt.ylabel(r"Normalized $K$")
plt.legend(loc=0)
plt.savefig("dcm_spectra_fit.png", dpi=900)

# %%
tetracene_dce_fit.explore_non_condon_orders(max_order = None, order_lists_to_calculate=o_list, method_str="voigt")
# Out:
# [1] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 10 better models were found
#
#
#  relative parameter errors for order[1]: [-48166111.525665924]
#
#
# check for big off-diagonal values:
# [[  2.15171289e-02   2.13885885e+14]
#  [  2.13885885e+14   3.04419119e+30]]
#
#
# HO/c model fit Found for voigt!  S=1.35096562295, c=[-36223830.72781194]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = -0.220423397127 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [2] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 6 better models were found
#
#
#  relative parameter errors for order[2]: [-0.019800458140437457]
#
#
# check for big off-diagonal values:
# [[  2.52166012e-03   2.01810589e-05]
#  [  2.01810589e-05   1.26964804e-06]]
#
#
# HO/c model fit Found for voigt!  S=2.00647986552, c=[-0.0569071]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.936745509298 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [1, 2] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 5 better models were found
#
#
#  relative parameter errors for order[1, 2]: [-11812748.070001459]
#
#
# check for big off-diagonal values:
# [[  1.28080006e-02  -7.80777768e+13  -2.89174384e+13]
#  [ -7.80777768e+13   3.85476116e+30   1.42767655e+30]
#  [ -2.89174384e+13   1.42767655e+30   5.28764366e+29]]
#
#
# HO/c model fit Found for voigt!  S=1.44297161968, c=[ -1.66206451e+08  -6.15573830e+07]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.314900616826 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [2, 4] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 8 better models were found
#
#
#  relative parameter errors for order[2, 4]: [-86974.983028123432]
#
#
# check for big off-diagonal values:
# [[  7.87205223e-02   1.22129189e+11  -2.67225728e+09]
#  [  1.22129190e+11   2.02431607e+24  -4.42933199e+22]
#  [ -2.67225729e+09  -4.42933199e+22   9.69165941e+20]]
#
#
# HO/c model fit Found for voigt!  S=1.16912024154, c=[ 16358532.61468262   -357935.45498245]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.785960156726 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [1, 3] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 5 better models were found
#
#
#  relative parameter errors for order[1, 3]: [-140046.92102288874]
#
#
# check for big off-diagonal values:
# [[  5.69017866e-02   1.80459028e+10  -4.74286689e+08]
#  [  1.80459028e+10   4.87471093e+22  -1.28118509e+21]
#  [ -4.74286689e+08  -1.28118509e+21   3.36724629e+19]]
#
#
# HO/c model fit Found for voigt!  S=0.641648088086, c=[ 1576523.16784459   -41434.66924874]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.820639502511 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [5, 3, 1] order non-condon perturbation calculation
#
# ---------VOIGT---------
#
# Through running 50 lstsq attempts, 2 better models were found
#
#
#  relative parameter errors for order[5, 3, 1]: [-0.10351509467424477]
#
#
# check for big off-diagonal values:
# [[  2.68335465e-02   5.98363086e-06  -7.26350866e-04   1.37337284e-02]
#  [  5.98363086e-06   8.34710757e-09  -4.88452282e-07   2.20152261e-06]
#  [ -7.26350866e-04  -4.88452282e-07   3.51210065e-05  -3.43918334e-04]
#  [  1.37337284e-02   2.20152261e-06  -3.43918334e-04   7.73256289e-03]]
#
#
# HO/c model fit Found for voigt!  S=1.39282473537, c=[  2.02383562e-04   4.74199410e-03  -8.49489562e-01]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.973139338649 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# [5, 3, 1] order non-condon perturbation fit the spectra best!
# cost report:
# (0.012699573939259655, [5, 3, 1])
# (0.20183316236973925, [2, 4])
# (0.21361231794741312, [2])
# (0.28071831732569696, [1, 2])
# (0.40965355769217016, [1, 3])
# (1.1943486680223585, [1])

# %%
tetracene_toluene_fit.fit_and_observe_non_condon_models([2], plot_spectra=False, my_methods_list=["voigt"])
plt.savefig("toluene_ratio_fit_2.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.65721203597, c=[-0.06008804]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.958162343631 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -10.7211600702 	 improvement_factor = nan

# %%
tetracene_dce_fit.fit_and_observe_non_condon_models([2], plot_spectra=False, my_methods_list=["voigt"])
plt.savefig("dcm_ratio_fit_2.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=2.00647986552, c=[-0.0569071]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.936745509298 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -8.28205412498 	 improvement_factor = nan

# %%
order = [2,4]
tfs=True
method = "voigt"
tetracene_dce_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method])
plt.savefig("dcm_ratio_fit_24.png")
tetracene_toluene_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method])
plt.savefig("toluene_ratio_fit_24.png", dpi=900)

x = np.linspace(-3,3)
tfs=False
plt.figure()
tetracene_dce_fit.plot_transition_dipole(x, c_order = order, method_str=method, label_prefix = "DCM")
tetracene_toluene_fit.plot_transition_dipole(x, c_order = order, method_str=method,  label_prefix="Toluene")
plt.legend(loc=0)
plt.title(r"Transition Dipole From $H_{%s}$"% order)
plt.savefig("dipole_comparison_24.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [2, 4]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.16912024154, c=[ 16358532.61468262   -357935.45498245]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.785960156726 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -6.90255833931 	 improvement_factor = nan
# PREPARING ANALYSIS FOR A [2, 4]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.42787962841, c=[-10.34675596   0.21528154]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.782918848916 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -7.59487896447 	 improvement_factor = nan
# ('test loc 2', [2, 4])
# [...c_i...] = [ 16358532.61468262   -357935.45498245]
# 16358532.6147 * x^2
# -357935.454982 * x^4
# ('test loc 2', [2, 4])
# [...c_i...] = [-10.34675596   0.21528154]
# -10.3467559595 * x^2
# 0.215281535166 * x^4

# %%
order = [1,3]
method = "voigt"
tfs=True
tetracene_dce_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method])
plt.savefig("dcm_ratio_fit_13.png")
tetracene_toluene_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method])
plt.savefig("toluene_ratio_fit_13.png", dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [1, 3]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=0.641648088086, c=[ 1576523.16784459   -41434.66924874]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.820639502511 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -6.0920759939 	 improvement_factor = nan
# PREPARING ANALYSIS FOR A [1, 3]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=0.737948570315, c=[-3.83083747  0.09088571]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.989470735081 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -7.09427451513 	 improvement_factor = nan

# %%
x = np.linspace(-3,3)
tfs=False
plt.figure()
tetracene_dce_fit.plot_transition_dipole(x, c_order = order, method_str=method, label_prefix = "DCM")
tetracene_toluene_fit.plot_transition_dipole(x, c_order = order, method_str=method, label_prefix="Toluene")
plt.legend(loc=0)
plt.title(r"Transition Dipole From $H_{%s}$"% order)
plt.savefig("dipole_comparison_13.png", dpi=900)
# Out:
# ('test loc 2', [1, 3])
# [...c_i...] = [ 1576523.16784459   -41434.66924874]
# 1576523.16784 * x^1
# -41434.6692487 * x^3
# ('test loc 2', [1, 3])
# [...c_i...] = [-3.83083747  0.09088571]
# -3.83083746586 * x^1
# 0.0908857147911 * x^3

# %%
PeakTools.table_generator([1,3], tetracene_dce_fit, "DCM", tetracene_toluene_fit, "Toluene")
# Out:
#   & DCM  &  Toluene \\
# $S_{ (1, 3) }$ & 0.642  &  0.738 \\
# $c'_{ 1 }$ & 1576523.168  &  -3.831 \\
# $c'_{ 3 }$ & -41434.669  &  0.091 \\
# $r^2_{ (1, 3) }$ & -6.092  &  -7.094 \\

# %%
order = [5,3,1]
tfs=True
method = "voigt"
tetracene_dce_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method])
plt.savefig("dcm_ratio_fit_{}.png".format(*order))
tetracene_toluene_fit.fit_and_observe_non_condon_models(order=order, plot_spectra=False, my_methods_list=[method])
plt.savefig("toluene_ratio_fit_{}.png".format(*order), dpi=900)

x = np.linspace(-3,3)
tfs=False
plt.figure()
tetracene_dce_fit.plot_transition_dipole(x, c_order = order, method_str=method, label_prefix = "DCM")
tetracene_toluene_fit.plot_transition_dipole(x, c_order = order, method_str=method, label_prefix="Toluene")
plt.legend(loc=0)
plt.title(r"Transition Dipole From $H_{%s}$"% order)
plt.savefig("dipole_comparison_{}.png".format(*order), dpi=900)
# Out:
# PREPARING ANALYSIS FOR A [5, 3, 1]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=1.39282473537, c=[  2.02383562e-04   4.74199410e-03  -8.49489562e-01]
# Naively S=1.7534906858 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.973139338649 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -8.81539721493 	 improvement_factor = nan
# PREPARING ANALYSIS FOR A [5, 3, 1]-ORDER CORRECTION TO TRANSITION DIPOLE:
#
#
# ---------VOIGT---------
#
# HO/c model fit Found for voigt!  S=0.713994164939, c=[-0.00136174  0.08132911 -1.25479226]
# Naively S=0.886141547618 without a non-condon correction
# peak height goddness of fit:
# r^2_condon = nan 	 r^2_model = 0.999999739669 	 improvement_factor = nan
#
#
#
# BEST METHOD WAS: voigt
# peak ratio goodness of fit:
# r^2_condon = nan 	 r^2_model = -6.99574003073 	 improvement_factor = nan
# ('test loc 2', [5, 3, 1])
# [...c_i...] = [  2.02383562e-04   4.74199410e-03  -8.49489562e-01]
# 0.000202383561982 * x^5
# 0.00474199410019 * x^3
# -0.849489561676 * x^1
# ('test loc 2', [5, 3, 1])
# [...c_i...] = [-0.00136174  0.08132911 -1.25479226]
# -0.00136173694678 * x^5
# 0.0813291102241 * x^3
# -1.25479226133 * x^1

# %%
PeakTools.table_generator(order, tetracene_dce_fit, "DCM", tetracene_toluene_fit, "Toluene")
# Out:
#   & DCM  &  Toluene \\
# $S_{ (5, 3, 1) }$ & 1.393  &  0.714 \\
# $c'_{ 5 }$ & 0.000  &  -0.001 \\
# $c'_{ 3 }$ & 0.005  &  0.081 \\
# $c'_{ 1 }$ & -0.849  &  -1.255 \\
# $r^2_{ (5, 3, 1) }$ & -8.815  &  -6.996 \\

# %%
a = np.array([[i * k for i in range(4)] for k in range(9)])

# %%
a.shape
# Out:
# (9, 4)
